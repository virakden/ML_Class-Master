# %% [markdown]
# Mlxtend (machine learning extensions) is a Python library of useful tools for the day-to-day data science tasks.

# %% [markdown]
# MLxtend is a Python library that provides a wide range of functionalities for machine learning and data analysis tasks. It stands for "machine learning extensions" and is built on top of other popular libraries like NumPy, SciPy, and scikit-learn. MLxtend offers implementations of various algorithms and tools that complement those already available in scikit-learn, as well as additional utilities for data preprocessing, model evaluation, and visualization.
#
# Some of the key features of MLxtend include:
#
# 1. Implementation of popular machine learning algorithms not available in scikit-learn.
# 2. Tools for feature selection and extraction.
# 3. Support for ensemble learning methods.
# 4. Evaluation metrics and visualization tools for assessing model performance.
# 5. Utility functions for working with datasets and preprocessing.

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from mlxtend) (1.14.1)
# Requirement already satisfied: numpy>=1.16.2 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from mlxtend) (2.2.3)
# Collecting scikit-learn>=1.3.1 (from mlxtend)
#   Downloading scikit_learn-1.6.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from mlxtend) (3.9.2)
# Collecting joblib>=0.13.2 (from mlxtend)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.3.1->mlxtend)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/aupp_course/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.1 MB/s eta 0:00:00a 0:00:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scikit_learn-1.6.1-cp310-cp310-macosx_12_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 1.6 MB/s eta 0:00:00a 0:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn, mlxtend
# Successfully installed joblib-1.4.2 mlxtend-0.23.4 scikit-learn-1.6.1 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ### Load and read datasets from local disk

# %% [markdown]
# Source: https://www.kaggle.com/sulmansarwar/transactions-from-a-bakery
#
# About Data:-
#
# __The dataset consists of 21293 observations from a bakery. The data file contains four variables, Date, Time, Transaction ID and Item. Transaction ID ranges from 1 through 9684. However, there are some skipped numbers in Transaction IDs. Also, there are duplicated entries, as shown in observation # 2 and #3. Besides, the Item contains "Adjustment", "NONE", and "Afternoon with the baker". While the entries of "Adjustment" and "NONE" are straight forward, "Afternoon with the baker" may be a real purchase.__
#
#
# Columns:-
# Date
# Time
# Transaction
# Item

# %% [markdown]
# ### Read and Load dataset from local disk

# %%
bread_basket_data = pd.read_csv('BreadBasket_DMS.csv')

bread_basket_data.head(100)
# Out:
#           Date      Time  Transaction           Item
# 0   2016-10-30  09:58:11            1          Bread
# 1   2016-10-30  10:05:34            2   Scandinavian
# 2   2016-10-30  10:05:34            2   Scandinavian
# 3   2016-10-30  10:07:57            3  Hot chocolate
# 4   2016-10-30  10:07:57            3            Jam
# ..         ...       ...          ...            ...
# 95  2016-10-30  12:05:47           44      Medialuna
# 96  2016-10-30  12:08:36           45         Coffee
# 97  2016-10-30  12:08:36           45  Hot chocolate
# 98  2016-10-30  12:08:36           45      Medialuna
# 99  2016-10-30  12:09:04           46         Coffee
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Shape of dataset

# %%
bread_basket_data.shape
# Out:
# (21293, 4)

# %% [markdown]
# ### Check `NONE` values

# %%
bread_basket_data.loc[bread_basket_data['Item'] == 'NONE'].count()
# Out:
# Date           786
# Time           786
# Transaction    786
# Item           786
# dtype: int64

# %% [markdown]
# ### Remove `NONE` values from dataset

# %%
bread_basket_data = bread_basket_data.drop(
    bread_basket_data.loc[bread_basket_data['Item'] == 'NONE'].index)

# %% [markdown]
# ### Again check `NONE` or `NAN` values

# %%
bread_basket_data.loc[bread_basket_data['Item'] == 'NONE'].count()
# Out:
# Date           0
# Time           0
# Transaction    0
# Item           0
# dtype: int64

# %% [markdown]
# ### Shape of dataset after removing `NONE` values

# %%
bread_basket_data.shape
# Out:
# (20507, 4)

# %% [markdown]
# ### Check unique values in `item set`

# %%
bread_basket_data['Item'].unique()
# Out:
# array(['Bread', 'Scandinavian', 'Hot chocolate', 'Jam', 'Cookies',
#        'Muffin', 'Coffee', 'Pastry', 'Medialuna', 'Tea', 'Tartine',
#        'Basket', 'Mineral water', 'Farm House', 'Fudge', 'Juice',
#        "Ella's Kitchen Pouches", 'Victorian Sponge', 'Frittata',
#        'Hearty & Seasonal', 'Soup', 'Pick and Mix Bowls', 'Smoothies',
#        'Cake', 'Mighty Protein', 'Chicken sand', 'Coke',
#        'My-5 Fruit Shoot', 'Focaccia', 'Sandwich', 'Alfajores', 'Eggs',
#        'Brownie', 'Dulce de Leche', 'Honey', 'The BART', 'Granola',
#        'Fairy Doors', 'Empanadas', 'Keeping It Local', 'Art Tray',
#        'Bowl Nic Pitt', 'Bread Pudding', 'Adjustment', 'Truffles',
#        'Chimichurri Oil', 'Bacon', 'Spread', 'Kids biscuit', 'Siblings',
#        'Caramel bites', 'Jammie Dodgers', 'Tiffin', 'Olum & polenta',
#        'Polenta', 'The Nomad', 'Hack the stack', 'Bakewell',
#        'Lemon and coconut', 'Toast', 'Scone', 'Crepes', 'Vegan mincepie',
#        'Bare Popcorn', 'Muesli', 'Crisps', 'Pintxos', 'Gingerbread syrup',
#        'Panatone', 'Brioche and salami', 'Afternoon with the baker',
#        'Salad', 'Chicken Stew', 'Spanish Brunch',
#        'Raspberry shortbread sandwich', 'Extra Salami or Feta',
#        'Duck egg', 'Baguette', "Valentine's card", 'Tshirt',
#        'Vegan Feast', 'Postcard', 'Nomad bag', 'Chocolates',
#        'Coffee granules ', 'Drinking chocolate spoons ',
#        'Christmas common', 'Argentina Night', 'Half slice Monster ',
#        'Gift voucher', 'Cherry me Dried fruit', 'Mortimer', 'Raw bars',
#        'Tacos/Fajita'], dtype=object)

# %% [markdown]
# ### Calculating Frequency of each item

# %%
basket_items = {}

for item in bread_basket_data['Item']:
    if item in basket_items:
        basket_items[item] = basket_items[item] + 1
    else:
        basket_items[item] = 1

# %%
basket_items
# Out:
# {'Bread': 3325,
#  'Scandinavian': 277,
#  'Hot chocolate': 590,
#  'Jam': 149,
#  'Cookies': 540,
#  'Muffin': 370,
#  'Coffee': 5471,
#  'Pastry': 856,
#  'Medialuna': 616,
#  'Tea': 1435,
#  'Tartine': 47,
#  'Basket': 6,
#  'Mineral water': 136,
#  'Farm House': 374,
#  'Fudge': 159,
#  'Juice': 369,
#  "Ella's Kitchen Pouches": 17,
#  'Victorian Sponge': 7,
#  'Frittata': 81,
#  'Hearty & Seasonal': 107,
#  'Soup': 342,
#  'Pick and Mix Bowls': 12,
#  'Smoothies': 77,
#  'Cake': 1025,
#  'Mighty Protein': 11,
#  'Chicken sand': 1,
#  'Coke': 185,
#  'My-5 Fruit Shoot': 18,
#  'Focaccia': 54,
#  'Sandwich': 771,
#  'Alfajores': 369,
#  'Eggs': 28,
#  'Brownie': 379,
#  'Dulce de Leche': 13,
#  'Honey': 6,
#  'The BART': 1,
#  'Granola': 28,
#  'Fairy Doors': 2,
#  'Empanadas': 7,
#  'Keeping It Local': 63,
#  'Art Tray': 38,
#  'Bowl Nic Pitt': 2,
#  'Bread Pudding': 4,
#  'Adjustment': 1,
#  'Truffles': 193,
#  'Chimichurri Oil': 2,
#  'Bacon': 1,
#  'Spread': 2,
#  'Kids biscuit': 12,
#  'Siblings': 2,
#  'Caramel bites': 3,
#  'Jammie Dodgers': 125,
#  'Tiffin': 146,
#  'Olum & polenta': 1,
#  'Polenta': 1,
#  'The Nomad': 58,
#  'Hack the stack': 2,
#  'Bakewell': 48,
#  'Lemon and coconut': 6,
#  'Toast': 318,
#  'Scone': 327,
#  'Crepes': 6,
#  'Vegan mincepie': 54,
#  'Bare Popcorn': 5,
#  'Muesli': 8,
#  'Crisps': 14,
#  'Pintxos': 6,
#  'Gingerbread syrup': 9,
#  'Panatone': 5,
#  'Brioche and salami': 3,
#  'Afternoon with the baker': 44,
#  'Salad': 99,
#  'Chicken Stew': 123,
#  'Spanish Brunch': 172,
#  'Raspberry shortbread sandwich': 3,
#  'Extra Salami or Feta': 38,
#  'Duck egg': 12,
#  'Baguette': 152,
#  "Valentine's card": 13,
#  'Tshirt': 21,
#  'Vegan Feast': 16,
#  'Postcard': 10,
#  'Nomad bag': 8,
#  'Chocolates': 10,
#  'Coffee granules ': 7,
#  'Drinking chocolate spoons ': 8,
#  'Christmas common': 11,
#  'Argentina Night': 7,
#  'Half slice Monster ': 6,
#  'Gift voucher': 1,
#  'Cherry me Dried fruit': 3,
#  'Mortimer': 5,
#  'Raw bars': 1,
#  'Tacos/Fajita': 11}

# %%
item_names = []
item_frequencies = []

for key, val in basket_items.items():
    item_names.append(key)
    item_frequencies.append(val)

# %%
items_table = pd.DataFrame({'Names': item_names,
                            'Frequencies': item_frequencies})

items_table
# Out:
#                     Names  Frequencies
# 0                   Bread         3325
# 1            Scandinavian          277
# 2           Hot chocolate          590
# 3                     Jam          149
# 4                 Cookies          540
# ..                    ...          ...
# 89           Gift voucher            1
# 90  Cherry me Dried fruit            3
# 91               Mortimer            5
# 92               Raw bars            1
# 93           Tacos/Fajita           11
#
# [94 rows x 2 columns]

# %% [markdown]
# ### Plotting Bar plot for items vs frequency

# %%
items_table.sort_values('Frequencies', ascending=False).head()
# Out:
#      Names  Frequencies
# 6   Coffee         5471
# 0    Bread         3325
# 9      Tea         1435
# 23    Cake         1025
# 7   Pastry          856

# %%
items_table.plot.bar(y='Frequencies', x='Names', figsize=(12, 8))
# Out:
# <Axes: xlabel='Names'>

# %%
items_table.sort_values('Frequencies', ascending=False).head(20).\
    plot.bar(y='Frequencies', x='Names', figsize=(12, 8))
# Out:
# <Axes: xlabel='Names'>

# %% [markdown]
# ### Describe dataset

# %%
bread_basket_data['Transaction'].describe()
# Out:
# count    20507.000000
# mean      4976.202370
# std       2796.203001
# min          1.000000
# 25%       2552.000000
# 50%       5137.000000
# 75%       7357.000000
# max       9684.000000
# Name: Transaction, dtype: float64

# %% [markdown]
# ### Group items with same transaction  Id
# https://stackoverflow.com/questions/53781634/aggregation-in-pandas

# %%
bread_basket_data = bread_basket_data.groupby('Transaction').agg(','.join).reset_index()

bread_basket_data = bread_basket_data.drop(['Date', 'Time'], axis=1)
bread_basket_data.head(10)
# Out:
#    Transaction                         Item
# 0            1                        Bread
# 1            2    Scandinavian,Scandinavian
# 2            3    Hot chocolate,Jam,Cookies
# 3            4                       Muffin
# 4            5          Coffee,Pastry,Bread
# 5            6      Medialuna,Pastry,Muffin
# 6            7  Medialuna,Pastry,Coffee,Tea
# 7            8                 Pastry,Bread
# 8            9                 Bread,Muffin
# 9           10       Scandinavian,Medialuna

# %%
bread_basket_data.shape
# Out:
# (9465, 2)

# %% [markdown]
# ### Take items sets

# %%
items_data = bread_basket_data['Item']

items_data.head(10)
# Out:
# 0                          Bread
# 1      Scandinavian,Scandinavian
# 2      Hot chocolate,Jam,Cookies
# 3                         Muffin
# 4            Coffee,Pastry,Bread
# 5        Medialuna,Pastry,Muffin
# 6    Medialuna,Pastry,Coffee,Tea
# 7                   Pastry,Bread
# 8                   Bread,Muffin
# 9         Scandinavian,Medialuna
# Name: Item, dtype: object

# %% [markdown]
# ### Convert into list and split each item in a list

# %%
items_list = [item.split(',') for item in items_data]

items_list_df = pd.DataFrame({'Items': items_list})

items_list_df.head(10)
# Out:
#                               Items
# 0                           [Bread]
# 1      [Scandinavian, Scandinavian]
# 2     [Hot chocolate, Jam, Cookies]
# 3                          [Muffin]
# 4           [Coffee, Pastry, Bread]
# 5       [Medialuna, Pastry, Muffin]
# 6  [Medialuna, Pastry, Coffee, Tea]
# 7                   [Pastry, Bread]
# 8                   [Bread, Muffin]
# 9         [Scandinavian, Medialuna]

# %% [markdown]
# ### Association Rule Mining
# * __1. Encoding and transform__
#
#
# http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

transencoder = TransactionEncoder()

transencoder_array = transencoder.fit(items_list).transform(items_list)

# %%
encoded_df = pd.DataFrame(transencoder_array, columns=transencoder.columns_)

encoded_df.head(10)
# Out:
#    Adjustment  Afternoon with the baker  Alfajores  Argentina Night  Art Tray  \
# 0       False                     False      False            False     False
# 1       False                     False      False            False     False
# 2       False                     False      False            False     False
# 3       False                     False      False            False     False
# 4       False                     False      False            False     False
# 5       False                     False      False            False     False
# 6       False                     False      False            False     False
# 7       False                     False      False            False     False
# 8       False                     False      False            False     False
# 9       False                     False      False            False     False
#
#    Bacon  Baguette  Bakewell  Bare Popcorn  Basket  ...  The BART  The Nomad  \
# 0  False     False     False         False   False  ...     False      False
# 1  False     False     False         False   False  ...     False      False
# 2  False     False     False         False   False  ...     False      False
# 3  False     False     False         False   False  ...     False      False
# 4  False     False     False         False   False  ...     False      False
# 5  False     False     False         False   False  ...     False      False
# 6  False     False     False         False   False  ...     False      False
# 7  False     False     False         False   False  ...     False      False
# 8  False     False     False         False   False  ...     False      False
# 9  False     False     False         False   False  ...     False      False
#
#    Tiffin  Toast  Truffles  Tshirt  Valentine's card  Vegan Feast  \
# 0   False  False     False   False             False        False
# 1   False  False     False   False             False        False
# 2   False  False     False   False             False        False
# 3   False  False     False   False             False        False
# 4   False  False     False   False             False        False
# 5   False  False     False   False             False        False
# 6   False  False     False   False             False        False
# 7   False  False     False   False             False        False
# 8   False  False     False   False             False        False
# 9   False  False     False   False             False        False
#
#    Vegan mincepie  Victorian Sponge
# 0           False             False
# 1           False             False
# 2           False             False
# 3           False             False
# 4           False             False
# 5           False             False
# 6           False             False
# 7           False             False
# 8           False             False
# 9           False             False
#
# [10 rows x 94 columns]

# %% [markdown]
# ### Support of each item sets

# %%
item_support_df = apriori(encoded_df, min_support=0.01, use_colnames=True)

item_support_df.shape
# Out:
# (61, 2)

# %%
item_support_df.sample(10)
# Out:
#      support           itemsets
# 40  0.028104       (Bread, Tea)
# 8   0.054411          (Cookies)
# 34  0.090016    (Coffee, Bread)
# 42  0.054728     (Coffee, Cake)
# 7   0.019440             (Coke)
# 45  0.028209  (Cookies, Coffee)
# 47  0.020602    (Juice, Coffee)
# 5   0.012995     (Chicken Stew)
# 28  0.033597            (Toast)
# 10  0.015003            (Fudge)

# %% [markdown]
# ### Association rules
#
# https://www.pydoc.io/pypi/mlxtend-0.7.0/autoapi/frequent_patterns/association_rules/index.html

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(item_support_df, 
                          metric='confidence', min_threshold=0.1)

rules.shape
# Out:
# (44, 14)

# %%
rules.sample(30)
# Out:
#          antecedents      consequents  antecedent support  consequent support  \
# 28  (Spanish Brunch)         (Coffee)            0.018172            0.478394
# 14            (Cake)         (Coffee)            0.103856            0.478394
# 2          (Brownie)          (Bread)            0.040042            0.327205
# 25        (Sandwich)         (Coffee)            0.071844            0.478394
# 3             (Cake)          (Bread)            0.103856            0.327205
# 15   (Hot chocolate)           (Cake)            0.058320            0.103856
# 42    (Coffee, Cake)            (Tea)            0.054728            0.142631
# 12         (Brownie)         (Coffee)            0.040042            0.478394
# 29          (Coffee)            (Tea)            0.478394            0.142631
# 7    (Hot chocolate)          (Bread)            0.058320            0.327205
# 13          (Coffee)           (Cake)            0.478394            0.103856
# 41     (Tea, Coffee)           (Cake)            0.049868            0.103856
# 0        (Alfajores)          (Bread)            0.036344            0.327205
# 19         (Cookies)         (Coffee)            0.054411            0.478394
# 33             (Tea)       (Sandwich)            0.142631            0.071844
# 22       (Medialuna)         (Coffee)            0.061807            0.478394
# 43       (Tea, Cake)         (Coffee)            0.023772            0.478394
# 20   (Hot chocolate)         (Coffee)            0.058320            0.478394
# 8        (Medialuna)          (Bread)            0.061807            0.327205
# 26           (Scone)         (Coffee)            0.034548            0.478394
# 16            (Cake)  (Hot chocolate)            0.103856            0.058320
# 39   (Bread, Coffee)         (Pastry)            0.090016            0.086107
# 37  (Pastry, Coffee)          (Bread)            0.047544            0.327205
# 31           (Toast)         (Coffee)            0.033597            0.478394
# 6          (Cookies)          (Bread)            0.054411            0.327205
# 4           (Coffee)          (Bread)            0.478394            0.327205
# 23          (Muffin)         (Coffee)            0.038457            0.478394
# 32        (Sandwich)            (Tea)            0.071844            0.142631
# 40          (Pastry)  (Bread, Coffee)            0.086107            0.090016
# 35    (Coffee, Cake)          (Bread)            0.054728            0.327205
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 28  0.010882    0.598837  1.251766               1.0  0.002189    1.300235
# 14  0.054728    0.526958  1.101515               1.0  0.005044    1.102664
# 2   0.010777    0.269129  0.822508               1.0 -0.002326    0.920538
# 25  0.038246    0.532353  1.112792               1.0  0.003877    1.115384
# 3   0.023349    0.224822  0.687097               1.0 -0.010633    0.867923
# 15  0.011410    0.195652  1.883874               1.0  0.005354    1.114125
# 42  0.010037    0.183398  1.285822               1.0  0.002231    1.049923
# 12  0.019651    0.490765  1.025860               1.0  0.000495    1.024293
# 29  0.049868    0.104240  0.730840               1.0 -0.018366    0.957142
# 7   0.013418    0.230072  0.703144               1.0 -0.005665    0.873841
# 13  0.054728    0.114399  1.101515               1.0  0.005044    1.011905
# 41  0.010037    0.201271  1.937977               1.0  0.004858    1.121962
# 0   0.010354    0.284884  0.870657               1.0 -0.001538    0.940818
# 19  0.028209    0.518447  1.083723               1.0  0.002179    1.083174
# 33  0.014369    0.100741  1.402222               1.0  0.004122    1.032134
# 22  0.035182    0.569231  1.189878               1.0  0.005614    1.210871
# 43  0.010037    0.422222  0.882582               1.0 -0.001335    0.902779
# 20  0.029583    0.507246  1.060311               1.0  0.001683    1.058553
# 8   0.016904    0.273504  0.835879               1.0 -0.003319    0.926082
# 26  0.018067    0.522936  1.093107               1.0  0.001539    1.093366
# 16  0.011410    0.109868  1.883874               1.0  0.005354    1.057910
# 39  0.011199    0.124413  1.444872               1.0  0.003448    1.043749
# 37  0.011199    0.235556  0.719901               1.0 -0.004357    0.880109
# 31  0.023666    0.704403  1.472431               1.0  0.007593    1.764582
# 6   0.014474    0.266019  0.813004               1.0 -0.003329    0.916638
# 4   0.090016    0.188163  0.575059               1.0 -0.066517    0.828731
# 23  0.018806    0.489011  1.022193               1.0  0.000408    1.020777
# 32  0.014369    0.200000  1.402222               1.0  0.004122    1.071712
# 40  0.011199    0.130061  1.444872               1.0  0.003448    1.046033
# 35  0.010037    0.183398  0.560497               1.0 -0.007870    0.823895
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 28       0.204851  0.022406   0.230908    0.310792
# 14       0.102840  0.103745   0.093105    0.320679
# 2       -0.183536  0.030231  -0.086321    0.151032
# 25       0.109205  0.074701   0.103448    0.306150
# 3       -0.336947  0.057269  -0.152177    0.148091
# 15       0.498236  0.075683   0.102434    0.152760
# 42       0.235157  0.053582   0.047549    0.126884
# 12       0.026259  0.039398   0.023717    0.265921
# 29      -0.413856  0.087310  -0.044777    0.226935
# 7       -0.309550  0.036059  -0.144373    0.135540
# 13       0.176684  0.103745   0.011765    0.320679
# 41       0.509401  0.069853   0.108705    0.148957
# 0       -0.133570  0.029315  -0.062904    0.158264
# 19       0.081700  0.055905   0.076787    0.288707
# 33       0.334566  0.071806   0.031134    0.150370
# 22       0.170091  0.069665   0.174148    0.321387
# 43      -0.119934  0.020395  -0.107690    0.221601
# 20       0.060403  0.058333   0.055314    0.284542
# 8       -0.173062  0.045429  -0.079818    0.162584
# 26       0.088224  0.036507   0.085393    0.280350
# 16       0.523553  0.075683   0.054740    0.152760
# 39       0.338354  0.067905   0.041916    0.127237
# 37      -0.290026  0.030805  -0.136223    0.134891
# 31       0.332006  0.048464   0.433293    0.376936
# 6       -0.195651  0.039424  -0.090943    0.155128
# 4       -0.586210  0.125794  -0.206665    0.231634
# 23       0.022579  0.037760   0.020354    0.264161
# 32       0.309050  0.071806   0.066913    0.150370
# 40       0.336907  0.067905   0.044007    0.127237
# 35      -0.453411  0.026989  -0.213747    0.107036

# %%
rules.sort_values('confidence', ascending=False).head(10)
# Out:
#          antecedents consequents  antecedent support  consequent support  \
# 31           (Toast)    (Coffee)            0.033597            0.478394
# 28  (Spanish Brunch)    (Coffee)            0.018172            0.478394
# 22       (Medialuna)    (Coffee)            0.061807            0.478394
# 24          (Pastry)    (Coffee)            0.086107            0.478394
# 1        (Alfajores)    (Coffee)            0.036344            0.478394
# 21           (Juice)    (Coffee)            0.038563            0.478394
# 25        (Sandwich)    (Coffee)            0.071844            0.478394
# 14            (Cake)    (Coffee)            0.103856            0.478394
# 26           (Scone)    (Coffee)            0.034548            0.478394
# 19         (Cookies)    (Coffee)            0.054411            0.478394
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 31  0.023666    0.704403  1.472431               1.0  0.007593    1.764582
# 28  0.010882    0.598837  1.251766               1.0  0.002189    1.300235
# 22  0.035182    0.569231  1.189878               1.0  0.005614    1.210871
# 24  0.047544    0.552147  1.154168               1.0  0.006351    1.164682
# 1   0.019651    0.540698  1.130235               1.0  0.002264    1.135648
# 21  0.020602    0.534247  1.116750               1.0  0.002154    1.119919
# 25  0.038246    0.532353  1.112792               1.0  0.003877    1.115384
# 14  0.054728    0.526958  1.101515               1.0  0.005044    1.102664
# 26  0.018067    0.522936  1.093107               1.0  0.001539    1.093366
# 19  0.028209    0.518447  1.083723               1.0  0.002179    1.083174
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 31       0.332006  0.048464   0.433293    0.376936
# 28       0.204851  0.022406   0.230908    0.310792
# 22       0.170091  0.069665   0.174148    0.321387
# 24       0.146161  0.091968   0.141396    0.325764
# 1        0.119574  0.039693   0.119446    0.290888
# 21       0.108738  0.041507   0.107078    0.288656
# 25       0.109205  0.074701   0.103448    0.306150
# 14       0.102840  0.103745   0.093105    0.320679
# 26       0.088224  0.036507   0.085393    0.280350
# 19       0.081700  0.055905   0.076787    0.288707

# %%
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))

rules.sample(5)
# Out:
#         antecedents consequents  antecedent support  consequent support  \
# 29         (Coffee)       (Tea)            0.478394            0.142631
# 24         (Pastry)    (Coffee)            0.086107            0.478394
# 25       (Sandwich)    (Coffee)            0.071844            0.478394
# 19        (Cookies)    (Coffee)            0.054411            0.478394
# 34  (Bread, Coffee)      (Cake)            0.090016            0.103856
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 29  0.049868    0.104240  0.730840               1.0 -0.018366    0.957142
# 24  0.047544    0.552147  1.154168               1.0  0.006351    1.164682
# 25  0.038246    0.532353  1.112792               1.0  0.003877    1.115384
# 19  0.028209    0.518447  1.083723               1.0  0.002179    1.083174
# 34  0.010037    0.111502  1.073621               1.0  0.000688    1.008606
#
#     zhangs_metric   jaccard  certainty  kulczynski  antecedent_len
# 29      -0.413856  0.087310  -0.044777    0.226935               1
# 24       0.146161  0.091968   0.141396    0.325764               1
# 25       0.109205  0.074701   0.103448    0.306150               1
# 19       0.081700  0.055905   0.076787    0.288707               1
# 34       0.075356  0.054598   0.008532    0.104073               2

# %% [markdown]
# ### Select `antecedents` where item frequency is `'Pastry', 'Bread'`

# %%
rules[rules['antecedents'] == {'Pastry', 'Bread'}]
# Out:
#         antecedents consequents  antecedent support  consequent support  \
# 38  (Pastry, Bread)    (Coffee)             0.02916            0.478394
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 38  0.011199    0.384058  0.802807               1.0 -0.002751    0.846843
#
#     zhangs_metric   jaccard  certainty  kulczynski  antecedent_len
# 38       -0.20192  0.022563  -0.180857    0.203734               2

# %% [markdown]
# ### Select `antecedents` where item frequency is `Cake`

# %%
rules[rules['antecedents'] == {'Cake'}]
# Out:
#    antecedents      consequents  antecedent support  consequent support  \
# 3       (Cake)          (Bread)            0.103856            0.327205
# 14      (Cake)         (Coffee)            0.103856            0.478394
# 16      (Cake)  (Hot chocolate)            0.103856            0.058320
# 18      (Cake)            (Tea)            0.103856            0.142631
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 3   0.023349    0.224822  0.687097               1.0 -0.010633    0.867923
# 14  0.054728    0.526958  1.101515               1.0  0.005044    1.102664
# 16  0.011410    0.109868  1.883874               1.0  0.005354    1.057910
# 18  0.023772    0.228891  1.604781               1.0  0.008959    1.111865
#
#     zhangs_metric   jaccard  certainty  kulczynski  antecedent_len
# 3       -0.336947  0.057269  -0.152177    0.148091               1
# 14       0.102840  0.103745   0.093105    0.320679               1
# 16       0.523553  0.075683   0.054740    0.152760               1
# 18       0.420538  0.106736   0.100611    0.197779               1

# %%
rules[rules['antecedents'] == {'Sandwich'}]
# Out:
#    antecedents consequents  antecedent support  consequent support   support  \
# 10  (Sandwich)     (Bread)            0.071844            0.327205  0.017010
# 25  (Sandwich)    (Coffee)            0.071844            0.478394  0.038246
# 32  (Sandwich)       (Tea)            0.071844            0.142631  0.014369
#
#     confidence      lift  representativity  leverage  conviction  \
# 10    0.236765  0.723596               1.0 -0.006498    0.881503
# 25    0.532353  1.112792               1.0  0.003877    1.115384
# 32    0.200000  1.402222               1.0  0.004122    1.071712
#
#     zhangs_metric   jaccard  certainty  kulczynski  antecedent_len
# 10      -0.291561  0.044524  -0.134426    0.144375               1
# 25       0.109205  0.074701   0.103448    0.306150               1
# 32       0.309050  0.071806   0.066913    0.150370               1

# %%
#End of code

# %% [markdown]
# ## Homework 3
#
# Which item(s) are frequently bought together with `'Cake','Coffee'`

# %%
## TODO:

# %% [markdown]
# ### YOUR ANSWER:
#
# 1.
# 2.
# ...

# %% [markdown]
# ## Submission Site
#
# https://forms.gle/TPTg8zRdGjkBcd6y5
